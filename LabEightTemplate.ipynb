# %% [markdown]
# # MANE 3351
# ## Lab Eight
# ## My Name
# ## My Student ID Number

# %% [markdown]
# ## Root Finding Method
#
# *Describe the root finding method you selected for this lab and the reason for your selection.*

# %%
# Python code cell for Lab 8
# Enter your code below
